# %%
import pandas as pd
df = pd.read_csv('data.csv')
import matplotlib.pyplot as plt
import numpy as np
df
# Out:
#     ID        Date   Speedometer  Distance  Litres purchased  litres per km  \
# 0   24  12/15/2020        241427     389.3             34.96        11.1356
# 1   23   12/9/2020        241038     419.8             35.05        11.9772
# 2    1   12/3/2020        240618     374.2             32.13            NaN
# 3    7  11/30/2020        240244     433.3             33.42        12.9653
# 4   10  11/29/2020        239810     403.0             32.80        12.2866
# 5   17  11/28/2020        239407     427.9             37.38        11.4473
# 6   21  11/22/2020        238979     421.6             37.05        11.3792
# 7   22  11/18/2020        238558     424.3             37.20        11.4059
# 8   25  11/16/2020        238133     266.0             20.34        13.0777
# 9   26  11/15/2020        237867     404.3             34.42        11.7461
# 10  27  11/13/2020        237463     508.4             37.22        13.6593
# ...

# %%
garage = df.groupby('Garage')
garage.size()
# Out:
# Garage
# Caltex DLY            2
# Engen Burgersfort     1
# Engen Hatfield        1
# Engen Killner Park    7
# Engen Mooirivier      1
# Engen Wayverly        1
# Fouriesburg Caltex    1
# Harrysmith Shell      1
# Sasol Killner Park    4
# Sasol Stormvoël       1
# Shell N14             1
# Total Potch           1
# Total Stormvoël       1
# dtype: int64

# %%
garage.TotalCost.sum().plot(kind='barh')

# %%
df.shape
# Out:
# (23, 9)

# %%
df.dropna()
# Out:
#     ID        Date   Speedometer  Distance  Litres purchased  litres per km  \
# 0   24  12/15/2020        241427     389.3             34.96        11.1356
# 1   23   12/9/2020        241038     419.8             35.05        11.9772
# 3    7  11/30/2020        240244     433.3             33.42        12.9653
# 4   10  11/29/2020        239810     403.0             32.80        12.2866
# 5   17  11/28/2020        239407     427.9             37.38        11.4473
# 6   21  11/22/2020        238979     421.6             37.05        11.3792
# 7   22  11/18/2020        238558     424.3             37.20        11.4059
# 8   25  11/16/2020        238133     266.0             20.34        13.0777
# 9   26  11/15/2020        237867     404.3             34.42        11.7461
# 10  27  11/13/2020        237463     508.4             37.22        13.6593
# 11  28   11/9/2020        236954     543.9             37.08        14.6683
# ...

# %%
df.shape
# Out:
# (23, 9)
